# %% [markdown]
# # Extract Historical Data From PurpleAir Sensors
# We need to extract historical data from PurpleAir sensors in McKinley Park. To account for seasonal variability, we wanted to collect a 3 week summer dataset (1st-20th July 2021) and a 3 week winter dataset (1st - 20th Jan 2021). In order to collect historical data, we first have to use the PurpleAir API to get the Thingspeak API keys and sensor IDs. We then pull the data from Thingspeak. Unfortunately, Thingspeak has a date limit and does not keep data older than about 3 1/2 months. For this reason, we will pull the oldest and newest data possible.

# %%
import os
os.chdir('../')

from datetime import datetime
import pandas as pd
from src.config import PURPLE_AIR_KEY
from src.data import pull_purpleair_data, pull_purpleair_historical

# %% [markdown]
# ## Create list of Thingspeak IDs and keys

# %%
# pull list of PurpleAir sensors from JSON file
sensor_df = pd.read_json("data/pa_sensors.json")

# create dataframe for McKinley Park sensors
pa_sensor_df = pull_purpleair_data(sensor_df, "Chicago", "McKinley Park", PURPLE_AIR_KEY)

# %%
pa_sensor_df
# Out:
#       ID                    Label DEVICE_LOCATIONTYPE THINGSPEAK_PRIMARY_ID  \
# 0  96035         36th and Paulina             outside               1267967
# 1  96036       36th and Paulina B                 NaN               1267969
# 2  96395        38th & Winchester             outside               1271673
# 3  96396      38th & Winchester B                 NaN               1271675
# 4  94975    39th and Damen (NLEI)             outside               1261965
# 5  94976  39th and Damen (NLEI) B                 NaN               1261967
#
#   THINGSPEAK_PRIMARY_ID_READ_KEY THINGSPEAK_SECONDARY_ID  \
# 0               6AB8IRLJJPKIFME0                 1267968
# 1               L3Y8P2IWC9NY4HLO                 1267970
# 2               5REK7K675FMHLXCU                 1271674
# 3               324MUY4V609SF5M0                 1271676
# 4               UKYER4XQP4R4KLVQ                 1261966
# 5               YUSL71LBU2F7DJAJ                 1261968
#
#   THINGSPEAK_SECONDARY_ID_READ_KEY        Lat        Lon PM2_5Value  ...  \
# 0                 IQGCXB0M8CAHLMS0  41.828648 -87.667904      10.57  ...
# 1                 GAT5RETWAAN58851  41.828648 -87.667904      12.68  ...
# 2                 KA997C774A3QL4TS  41.824900 -87.673881      11.24  ...
# 3                 1M5DI7CI7619WP4T  41.824900 -87.673881      12.62  ...
# 4                 Y794X5FD2TG5A0JG  41.822733 -87.675820      24.98  ...
# 5                 699P8NZTP8ELMOQR  41.822733 -87.675820      28.88  ...
#
#    pm10_0_atm isOwner humidity temp_f pressure AGE  \
# 0       11.81       0       31     53   1006.6   1
# 1       12.68       0      NaN    NaN      NaN   1
# 2       11.97       0       29     53   1005.8   1
# 3       13.25       0       33     54   1005.3   1
# 4       28.05       0       20     62  1005.47   1
# 5       32.56       0      NaN    NaN      NaN   1
#
#                                                Stats  ParentID  Flag   Voc
# 0  {"v":10.57,"v1":9.21,"v2":8.01,"v3":9.1,"v4":1...       NaN   NaN   NaN
# 1  {"v":12.68,"v1":12.38,"v2":12.27,"v3":13.48,"v...   96035.0   1.0   NaN
# 2  {"v":11.24,"v1":10.19,"v2":9.01,"v3":10.37,"v4...       NaN   NaN   NaN
# 3  {"v":12.62,"v1":9.94,"v2":8.83,"v3":10.34,"v4"...   96395.0   NaN  37.0
# 4  {"v":24.98,"v1":13.4,"v2":11.08,"v3":12.7,"v4"...       NaN   NaN   NaN
# 5  {"v":28.88,"v1":15.41,"v2":12.73,"v3":14.36,"v...   94975.0   NaN   NaN
#
# [6 rows x 43 columns]

# %%
# create a dictionary of primary Thingspeaks IDs and keys
id_dict = {}
for idx in pa_sensor_df[~pa_sensor_df.Label.str.endswith('B')].index:
    id_dict[pa_sensor_df.loc[idx,'ID']]= {
        'ThingspeakID': pa_sensor_df.loc[idx,'THINGSPEAK_PRIMARY_ID'],
        'ThingspeakKey': pa_sensor_df.loc[idx,'THINGSPEAK_PRIMARY_ID_READ_KEY'],
        'Location': pa_sensor_df.loc[idx,'Label']
    }

# %%
id_dict
# Out:
# {96035: {'ThingspeakID': '1267967',
#   'ThingspeakKey': '6AB8IRLJJPKIFME0',
#   'Location': '36th and Paulina'},
#  96395: {'ThingspeakID': '1271673',
#   'ThingspeakKey': '5REK7K675FMHLXCU',
#   'Location': '38th & Winchester'},
#  94975: {'ThingspeakID': '1261965',
#   'ThingspeakKey': 'UKYER4XQP4R4KLVQ',
#   'Location': '39th and Damen (NLEI)'}}

# %%
# create a dictionary of secondary purpleair sensors
id_dict_b = {}
for idx in pa_sensor_df[pa_sensor_df.Label.str.endswith('B')].index:
    id_dict_b[pa_sensor_df.loc[idx,'ID']]= {
        'ThingspeakID_B': pa_sensor_df.loc[idx,'THINGSPEAK_PRIMARY_ID'],
        'ThingspeakKey_B': pa_sensor_df.loc[idx,'THINGSPEAK_PRIMARY_ID_READ_KEY']
    }

# %%
id_dict_b
# Out:
# {96036: {'ThingspeakID_B': '1267969', 'ThingspeakKey_B': 'L3Y8P2IWC9NY4HLO'},
#  96396: {'ThingspeakID_B': '1271675', 'ThingspeakKey_B': '324MUY4V609SF5M0'},
#  94976: {'ThingspeakID_B': '1261967', 'ThingspeakKey_B': 'YUSL71LBU2F7DJAJ'}}

# %% [markdown]
# ## Pull June PurpleAir Data

# %%
# define Thingspeak column labels
PARENT_PRIMARY_COLS = {
    'created_at': 'created_at',
    'entry_id': 'entry_id',
    'field1': 'PM1.0 (CF=1) ug/m3',
    'field2': 'PM2.5 (CF=1) ug/m3',
    'field3': 'PM10.0 (CF=1) ug/m3',
    'field4': 'UptimeMinutes',
    'field5': 'ADC',
    'field6': 'Temperature_F',
    'field7': 'Humidity_%',
    'field8': 'PM2.5 (CF=ATM) ug/m3',
}

PARENT_SECONDARY_COLS = {
    'created_at': 'created_at',
    'entry_id': 'entry_id',
    'field1': '0.3um/dl',
    'field2': '0.5um/dl',
    'field3': '1.0um/dl',
    'field4': '2.5um/dl',
    'field5': '5.0um/dl',
    'field6': '10.0um/dl',
    'field7': 'PM1.0 (CF=ATM) ug/m3',
    'field8': 'PM10 (CF=ATM) ug/m3',
}

CHILD_PRIMARY_COLS = {
    'created_at': 'created_at',
    'entry_id': 'entry_id',
    'field1': 'PM1.0 (CF=1) ug/m3',
    'field2': 'PM2.5 (CF=1) ug/m3',
    'field3': 'PM10.0 (CF=1) ug/m3',
    'field4': 'UptimeMinutes',
    'field5': 'RSSI_dbm',
    'field6': 'Atmospheric Pressure',
    'field7': 'gas_sensor',
    'field8': 'PM2.5 (CF=ATM) ug/m3',
}

CHILD_SECONDARY_COLS = {
    'created_at': 'created_at',
    'entry_id': 'entry_id',
    'field1': '0.3um/dl',
    'field2': '0.5um/dl',
    'field3': '1.0um/dl',
    'field4': '2.5um/dl',
    'field5': '5.0um/dl',
    'field6': '10.0um/dl',
    'field7': 'PM1.0 (CF=ATM) ug/m3',
    'field8': 'PM10 (CF=ATM) ug/m3'
}

# %%
# create PurpleAir sensor dataframe
pa_sensor_df = pd.DataFrame(columns=PARENT_PRIMARY_COLS.values())
pa_sensor_df['sensor'] = ''

# iterate through primary sensor data
for sensor in id_dict.keys():
    # pull sensor data
    df = pull_purpleair_historical(
        weeks_to_get=3,
        channel=id_dict[sensor]['ThingspeakID'],
        key=id_dict[sensor]['ThingspeakKey'],
        col_names=PARENT_PRIMARY_COLS,
        start_date=datetime(2021, 8, 1, 21, 32, 15, 259245)
    )
    df['sensor'] = sensor
    
    # append to pa_sensor_df
    pa_sensor_df = pd.concat([pa_sensor_df, df])

# %%
pa_sensor_df.head()
# Out:
#                      created_at entry_id  PM1.0 (CF=1) ug/m3  \
# 14601 2021-07-25 00:01:48+00:00      NaN                8.61
# 14602 2021-07-25 00:03:48+00:00      NaN                8.48
# 14603 2021-07-25 00:05:48+00:00      NaN                7.77
# 14604 2021-07-25 00:07:48+00:00      NaN               10.36
# 14605 2021-07-25 00:09:48+00:00      NaN               10.26
#
#        PM2.5 (CF=1) ug/m3  PM10.0 (CF=1) ug/m3  UptimeMinutes   ADC  \
# 14601               14.74                14.81          496.0 -63.0
# 14602               13.27                14.07          498.0 -64.0
# 14603               13.74                14.98          500.0 -63.0
# 14604               18.11                19.79          502.0 -62.0
# 14605               18.68                19.58          504.0 -65.0
#
#        Temperature_F  Humidity_%  PM2.5 (CF=ATM) ug/m3 sensor  channel
# 14601           87.0        65.0                 14.74  96035  1267967
# 14602           87.0        66.0                 13.27  96035  1267967
# 14603           86.0        67.0                 13.74  96035  1267967
# 14604           87.0        67.0                 18.11  96035  1267967
# 14605           87.0        66.0                 18.68  96035  1267967

# %%
pa_sensor_df.created_at.dt.day.nunique()
# Out:
# 28

# %%
pa_sensor_df.to_csv('data/summer_2021_pa_parent.csv')

# %%
# create PurpleAir sensor B dataframe
pa_sensor_b_df = pd.DataFrame(columns=CHILD_PRIMARY_COLS.values())
pa_sensor_b_df['sensor'] = ''

# iterate through primary sensor data
for sensor in id_dict_b.keys():
    # pull sensor data
    df = pull_purpleair_historical(
        weeks_to_get=3,
        channel=id_dict_b[sensor]['ThingspeakID_B'],
        key=id_dict_b[sensor]['ThingspeakKey_B'],
        col_names=CHILD_PRIMARY_COLS,
        start_date=datetime(2021, 8, 1, 21, 32, 15, 259245)
    )
    df['sensor'] = sensor
    
    # append to pa_sensor_df
    pa_sensor_b_df = pd.concat([pa_sensor_b_df, df])

# %%
pa_sensor_b_df.head()
# Out:
#                      created_at entry_id  PM1.0 (CF=1) ug/m3  \
# 14601 2021-07-25 00:01:50+00:00      NaN               11.16
# 14602 2021-07-25 00:03:50+00:00      NaN                9.53
# 14603 2021-07-25 00:05:50+00:00      NaN                9.91
# 14604 2021-07-25 00:07:51+00:00      NaN               11.02
# 14605 2021-07-25 00:09:51+00:00      NaN               11.81
#
#        PM2.5 (CF=1) ug/m3  PM10.0 (CF=1) ug/m3  UptimeMinutes  RSSI_dbm  \
# 14601               15.95                16.02        18240.0       0.0
# 14602               14.09                15.45        18240.0       0.0
# 14603               15.81                17.24        18072.0       0.0
# 14604               17.24                18.46        18240.0       0.0
# 14605               18.02                19.37        18240.0       0.0
#
#        Atmospheric Pressure  gas_sensor  PM2.5 (CF=ATM) ug/m3 sensor  channel
# 14601                990.22         NaN                 15.95  96036  1267969
# 14602                990.32         NaN                 14.09  96036  1267969
# 14603                990.31         NaN                 15.81  96036  1267969
# 14604                990.20         NaN                 17.24  96036  1267969
# 14605                990.10         NaN                 18.02  96036  1267969

# %%
pa_sensor_b_df.created_at.dt.day.nunique()
# Out:
# 28

# %%
pa_sensor_b_df.to_csv('data/summer_2021_pa_child.csv')

# %% [markdown]
# # Pull Autumn 2021 Data

# %%
# create PurpleAir sensor dataframe
pa_sensor_df2 = pd.DataFrame(columns=PARENT_PRIMARY_COLS.values())
pa_sensor_df2['sensor'] = ''

# iterate through primary sensor data
for sensor in id_dict.keys():
    # pull sensor data
    df = pull_purpleair_historical(
        weeks_to_get=3,
        channel=id_dict[sensor]['ThingspeakID'],
        key=id_dict[sensor]['ThingspeakKey'],
        col_names=PARENT_PRIMARY_COLS,
        start_date=datetime(2021, 11, 2, 21, 32, 15, 259245)
    )
    df['sensor'] = sensor
    
    # append to pa_sensor_df
    pa_sensor_df2 = pd.concat([pa_sensor_df2, df])

# %%
pa_sensor_df2.head()
# Out:
#                      created_at entry_id  PM1.0 (CF=1) ug/m3  \
# 81264 2021-10-26 00:00:39+00:00      NaN                1.23
# 81265 2021-10-26 00:02:39+00:00      NaN                0.37
# 81266 2021-10-26 00:04:39+00:00      NaN                0.93
# 81267 2021-10-26 00:06:39+00:00      NaN                0.98
# 81268 2021-10-26 00:08:39+00:00      NaN                0.68
#
#        PM2.5 (CF=1) ug/m3  PM10.0 (CF=1) ug/m3  UptimeMinutes   ADC  \
# 81264                2.59                 2.59         3822.0 -64.0
# 81265                1.03                 1.25         3824.0 -63.0
# 81266                1.84                 2.11         3826.0 -61.0
# 81267                1.67                 2.33         3828.0 -65.0
# 81268                1.33                 1.33         3830.0 -62.0
#
#        Temperature_F  Humidity_%  PM2.5 (CF=ATM) ug/m3 sensor  channel
# 81264           55.0        57.0                  2.59  96035  1267967
# 81265           55.0        57.0                  1.03  96035  1267967
# 81266           55.0        57.0                  1.84  96035  1267967
# 81267           55.0        57.0                  1.67  96035  1267967
# 81268           55.0        57.0                  1.33  96035  1267967

# %%
pa_sensor_df2.created_at.dt.day.nunique()
# Out:
# 28

# %%
pa_sensor_df2.to_csv('data/autumn_2021_pa_parent.csv')

# %%
# create PurpleAir sensor B dataframe
pa_sensor_b_df2 = pd.DataFrame(columns=CHILD_PRIMARY_COLS.values())
pa_sensor_b_df2['sensor'] = ''

# iterate through primary sensor data
for sensor in id_dict_b.keys():
    # pull sensor data
    df = pull_purpleair_historical(
        weeks_to_get=3,
        channel=id_dict_b[sensor]['ThingspeakID_B'],
        key=id_dict_b[sensor]['ThingspeakKey_B'],
        col_names=CHILD_PRIMARY_COLS,
        start_date=datetime(2021, 11, 2, 21, 32, 15, 259245)
    )
    df['sensor'] = sensor
    
    # append to pa_sensor_df
    pa_sensor_b_df2 = pd.concat([pa_sensor_b_df2, df])

# %%
pa_sensor_b_df2.head()
# Out:
#                      created_at entry_id  PM1.0 (CF=1) ug/m3  \
# 81279 2021-10-26 00:00:42+00:00      NaN                5.49
# 81280 2021-10-26 00:02:41+00:00      NaN                5.98
# 81281 2021-10-26 00:04:42+00:00      NaN                5.75
# 81282 2021-10-26 00:06:41+00:00      NaN                5.41
# 81283 2021-10-26 00:08:42+00:00      NaN                4.47
#
#        PM2.5 (CF=1) ug/m3  PM10.0 (CF=1) ug/m3  UptimeMinutes  RSSI_dbm  \
# 81279                6.37                 8.75        18296.0       0.0
# 81280                6.66                 8.52        18296.0       0.0
# 81281                6.69                 8.58        18296.0       0.0
# 81282                6.29                 8.00        18296.0       0.0
# 81283                5.14                 6.86        18464.0       0.0
#
#        Atmospheric Pressure  gas_sensor  PM2.5 (CF=ATM) ug/m3 sensor  channel
# 81279                996.51         NaN                  6.37  96036  1267969
# 81280                996.51         NaN                  6.66  96036  1267969
# 81281                996.58         NaN                  6.69  96036  1267969
# 81282                996.55         NaN                  6.29  96036  1267969
# 81283                996.59         NaN                  5.14  96036  1267969

# %%
pa_sensor_b_df2.to_csv('data/autumn_2021_pa_child.csv')
